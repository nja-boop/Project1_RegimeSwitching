# %% [markdown]
# imports pandas, numpy, yfinance, matplot, seaborn

# %%
# Core libraries
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inside notebook
# %matplotlib inline

# Style
sns.set(style="whitegrid")

# Check versions (optional but helpful)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
# Out:
# pandas: 2.0.3
# numpy: 1.24.3

# %% [markdown]
# downloads market data

# %%
import datetime as dt

start_date = dt.datetime(2015, 1, 1)
end_date = dt.datetime.today()

spy = yf.download('SPY', start=start_date, end=end_date, auto_adjust=True)['Close']
tlt = yf.download('TLT', start=start_date, end=end_date, auto_adjust=True)['Close']
gld = yf.download('GLD', start=start_date, end=end_date, auto_adjust=True)['Close']

data = pd.concat([spy, tlt, gld], axis=1)
data.columns = ['SPY', 'TLT', 'GLD']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# verifies market data

# %%
print(data.head())
print(data.tail())
# Out:
#                    SPY        TLT         GLD
# Date
# 2015-01-02  171.568039  96.512886  114.080002
# 2015-01-05  168.469574  98.028946  115.800003
# 2015-01-06  166.882736  99.795113  117.120003
# 2015-01-07  168.962326  99.598068  116.430000
# 2015-01-08  171.960556  98.279152  115.940002
#                    SPY        TLT         GLD
# Date
# 2025-08-04  631.169983  88.059998  310.910004
# 2025-08-05  627.969971  88.330002  311.160004
# 2025-08-06  632.780029  87.820000  310.500000
# 2025-08-07  632.250000  87.669998  313.119995
# 2025-08-08  637.179993  87.290001  313.049988

# %% [markdown]
# creates returns

# %%
returns = np.log(data / data.shift(1)).dropna()

# %% [markdown]
# verifies returns

# %%
print(returns.head())
print(returns.tail())
# Out:
#                  SPY       TLT       GLD
# Date
# 2015-01-05 -0.018225  0.015586  0.014965
# 2015-01-06 -0.009464  0.017856  0.011334
# 2015-01-07  0.012384 -0.001976 -0.005909
# 2015-01-08  0.017589 -0.013331 -0.004217
# 2015-01-09 -0.008046  0.010893  0.011321
#                  SPY       TLT       GLD
# Date
# 2025-08-04  0.015085  0.002729  0.005806
# 2025-08-05 -0.005083  0.003061  0.000804
# 2025-08-06  0.007631 -0.005791 -0.002123
# 2025-08-07 -0.000838 -0.001710  0.008403
# 2025-08-08  0.007767 -0.004344 -0.000224

# %% [markdown]
# saves returns

# %%
returns.to_csv("../data/returns.csv")

# %% [markdown]
# plots projections

# %%
data.plot(figsize=(12, 6), title="Price History of SPY, TLT, GLD")
plt.ylabel("Price")
plt.xlabel("Date")
plt.grid(True)
plt.show()

# %% [markdown]
# plots returns

# %%
returns.plot(figsize=(12, 6), title="Daily Log Returns")
plt.ylabel("Log Return")
plt.xlabel("Date")
plt.grid(True)
plt.show()
